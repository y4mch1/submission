# %% [markdown]
# # Proyek Analisis Data: Air-quality
# - **Nama:** Widian Sasi Disertasiani
# - **Email:** m004d4kx2669@bangkit.academy
# - **ID Dicoding:** widian_ogik

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana peningkatan polusi udara pada tahun 2013 hinga 2015?
#
# - Apakah ada bulan-bulan tertentu yang tingkat polusi udaranya selalu lebih tinggi?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
Aotizhongxin_df = pd.read_csv("PRSA_Data_Aotizhongxin_20130301-20170228.csv")
Aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
Changping_df = pd.read_csv("PRSA_Data_Changping_20130301-20170228.csv")
Changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
Dingling_df = pd.read_csv("PRSA_Data_Dingling_20130301-20170228.csv")
Dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
Dongsi_df = pd.read_csv("PRSA_Data_Dongsi_20130301-20170228.csv")
Dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
Guanyuan_df = pd.read_csv("PRSA_Data_Guanyuan_20130301-20170228.csv")
Guanyuan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
Gucheng_df = pd.read_csv("PRSA_Data_Gucheng_20130301-20170228.csv")
Gucheng_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %%
Huairou_df = pd.read_csv("PRSA_Data_Huairou_20130301-20170228.csv")
Huairou_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
Nongzhanguan_df = pd.read_csv("PRSA_Data_Nongzhanguan_20130301-20170228.csv")
Nongzhanguan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
Shunyi_df = pd.read_csv("PRSA_Data_Shunyi_20130301-20170228.csv")
Shunyi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
Tiantan_df = pd.read_csv("PRSA_Data_Tiantan_20130301-20170228.csv")
Tiantan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %%
Wanliu_df = pd.read_csv("PRSA_Data_Wanliu_20130301-20170228.csv")
Wanliu_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %%
Wanshouxigong_df = pd.read_csv("PRSA_Data_Wanshouxigong_20130301-20170228.csv")
Wanshouxigong_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# ### Assessing Data

# %%
Aotizhongxin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Aotizhongxin_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Aotizhongxin_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %%
Changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Changping_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Changping_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %%
Dingling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Dingling_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Dingling_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# ...

# %%
Dongsi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Dongsi_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Dongsi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# ...

# %%
Guanyuan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Guanyuan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Guanyuan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Guanyuan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# ...

# %%
Gucheng_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Gucheng_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       646
# PM10        381
# SO2         507
# NO2         668
# CO         1401
# O3          729
# TEMP         51
# PRES         50
# DEWP         51
# RAIN         43
# wd          159
# WSPM         42
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Gucheng_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Gucheng_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34418.000000  34683.000000  34557.000000  34396.000000  33663.000000
# mean      83.852089    118.861978     15.366162     55.871075   1323.974423
# ...

# %%
Huairou_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Huairou_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Huairou_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Huairou_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# mean      69.626367     91.482690     12.121553     32.497250   1022.554545
# ...

# %%
Nongzhanguan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Nongzhanguan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Nongzhanguan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Nongzhanguan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34436.000000  34624.000000  34618.000000  34372.000000  33858.000000
# mean      84.838483    108.991096     18.689242     58.097172   1324.350198
# ...

# %%
Shunyi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Shunyi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Shunyi_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Shunyi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# ...

# %%
Tiantan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Tiantan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Tiantan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Tiantan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34387.000000  34467.000000  33946.000000  34320.000000  33938.000000
# mean      82.164911    106.363672     14.367615     53.162646   1298.303318
# ...

# %%
Wanliu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Wanliu_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       382
# PM10        284
# SO2         575
# NO2        1070
# CO         1812
# O3         2107
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd          123
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Wanliu_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Wanliu_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34682.000000  34780.000000  34489.000000  33994.000000  33252.000000
# mean      83.374716    110.464618     18.376481     65.258789   1319.353513
# ...

# %%
Wanshouxigong_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Wanshouxigong_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Wanshouxigong_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Wanshouxigong_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2          NO2            CO  \
# count  34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# mean      85.024136    112.223459     17.148603     55.52956   1370.395031
# ...

# %% [markdown]
# ### Cleaning Data

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Aotizhongxin_df[column].fillna(value=Aotizhongxin_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Aotizhongxin_df.isna().sum())
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         81
# WSPM        0
# station     0
# dtype: int64

# %%
Aotizhongxin_df[Aotizhongxin_df.wd.isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO  \
# 6388    6389  2013     11   22     4   82.0   74.0  15.0   75.0  1300.0
# 11718  11719  2014      7    2     6   44.0   44.0   2.0   16.0   800.0
# 13412  13413  2014      9   10    20   56.0  141.0  13.0   81.0   700.0
# 16748  16749  2015      1   27    20   26.0   42.0  12.0   78.0  1300.0
# 17263  17264  2015      2   18     7   13.0   14.0  12.0   22.0   600.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...
# 34314  34315  2017      1   28    18  246.0  266.0  63.0   82.0   300.0
# 34334  34335  2017      1   29    14   15.0   55.0   4.0    6.0   300.0
# 34560  34561  2017      2    8     0  113.0  124.0  17.0  105.0  2600.0
# 34638  34639  2017      2   11     6   15.0   24.0  16.0   71.0   600.0
# 34746  34747  2017      2   15    18  269.0  269.0  51.0  129.0  3000.0
#
#                O3       TEMP        PRES       DEWP      RAIN   wd      WSPM  \
# ...

# %%
Aotizhongxin_df.wd.value_counts()
# Out:
# NE     5140
# ENE    3950
# SW     3359
# E      2608
# NNE    2445
# WSW    2212
# SSW    2098
# N      2066
# NW     1860
# ESE    1717
# NNW    1589
# SE     1341
# S      1304
# W      1171
# WNW    1101
# SSE    1022
# Name: wd, dtype: int64

# %%
Aotizhongxin_df.fillna(value="NE", inplace=True)

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Changping_df[column].fillna(value=Changping_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Changping_df.isna().sum())
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         140
# WSPM         0
# station      0
# dtype: int64

# %%
Changping_df[Changping_df.wd.isna()]
# Out:
#           No  year  month  day  hour       PM2.5        PM10        SO2  \
# 5107    5108  2013      9   29    19  162.000000  166.000000  16.000000
# 5110    5111  2013      9   29    22  224.000000  177.000000   9.424800
# 5111    5112  2013      9   29    23  193.000000  177.000000   9.000000
# 6389    6390  2013     11   22     5   93.000000  103.000000  22.000000
# 6411    6412  2013     11   23     3  131.000000  137.000000  41.000000
# ...      ...   ...    ...  ...   ...         ...         ...        ...
# 34296  34297  2017      1   28     0  218.000000  311.000000  56.000000
# 34447  34448  2017      2    3     7   74.000000   79.000000  30.000000
# 34519  34520  2017      2    6     7   26.000000   62.000000  22.000000
# 34538  34539  2017      2    7     2   34.000000   34.000000  14.000000
# 34873  34874  2017      2   21     1   71.099743   94.657871  14.958906
#
#              NO2           CO         O3   TEMP    PRES  DEWP  RAIN   wd  \
# ...

# %%
Changping_df.wd.value_counts()
# Out:
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: wd, dtype: int64

# %%
Changping_df.fillna(value="NNW", inplace=True)

# %%
Changping_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Dingling_df[column].fillna(value=Dingling_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Dingling_df.isna().sum())
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         140
# WSPM         0
# station      0
# dtype: int64

# %%
Dingling_df[Dingling_df.wd.isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO  \
# 5107    5108  2013      9   29    19  224.0  173.0   6.0   50.0  1200.0
# 5110    5111  2013      9   29    22  141.0   91.0   4.0   41.0  1200.0
# 5111    5112  2013      9   29    23  131.0   92.0   4.0   16.0  1200.0
# 6389    6390  2013     11   22     5   34.0   64.0  22.0   44.0   800.0
# 6411    6412  2013     11   23     3   98.0  111.0  31.0  103.0  1500.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...
# 34296  34297  2017      1   28     0   98.0  116.0  23.0   42.0  1100.0
# 34447  34448  2017      2    3     7   70.0   78.0  28.0   52.0  1800.0
# 34519  34520  2017      2    6     7    9.0    9.0   2.0    2.0   200.0
# 34538  34539  2017      2    7     2   33.0   33.0   9.0   26.0   900.0
# 34873  34874  2017      2   21     1   51.0   63.0  17.0   25.0  1400.0
#
#             O3   TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
Dingling_df.wd.value_counts()
# Out:
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: wd, dtype: int64

# %%
Dingling_df.fillna(value="NNW", inplace=True)

# %%
Dingling_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Dongsi_df[column].fillna(value=Dongsi_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Dongsi_df.isna().sum())
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         78
# WSPM        0
# station     0
# dtype: int64

# %%
Dongsi_df[Dongsi_df.wd.isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  \
# 16748  16749  2015      1   27    20   35.0   50.0  14.0   66.0  1000.0   2.0
# 17263  17264  2015      2   18     7   12.0   12.0   8.0   24.0   400.0  50.0
# 20853  20854  2015      7   17    21   89.0  111.0   4.0   72.0  1700.0  56.0
# 23035  23036  2015     10   16    19  295.0  318.0  40.0  177.0  2700.0  57.0
# 23059  23060  2015     10   17    19  357.0  375.0  22.0  215.0  3500.0   5.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...   ...
# 34314  34315  2017      1   28    18  258.0  350.0  58.0   79.0  3100.0   4.0
# 34334  34335  2017      1   29    14   15.0   68.0   3.0    8.0   300.0  67.0
# 34560  34561  2017      2    8     0  121.0  146.0  22.0   78.0  2300.0   6.0
# 34638  34639  2017      2   11     6   19.0   19.0  10.0   67.0  1100.0   5.0
# 34746  34747  2017      2   15    18  262.0  262.0  45.0  104.0  3000.0  44.0
#
# ...

# %%
Dongsi_df.wd.value_counts()
# Out:
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: wd, dtype: int64

# %%
Dongsi_df.fillna(value="ENE", inplace=True)

# %%
Dongsi_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Guanyuan_df[column].fillna(value=Guanyuan_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Guanyuan_df.isna().sum())
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         81
# WSPM        0
# station     0
# dtype: int64

# %%
Guanyuan_df[Guanyuan_df.wd.isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO  \
# 6388    6389  2013     11   22     4  125.0  151.0  34.0   87.0  3400.0
# 11718  11719  2014      7    2     6   45.0   45.0   2.0   15.0   800.0
# 13412  13413  2014      9   10    20   52.0   86.0  13.0   53.0   700.0
# 16748  16749  2015      1   27    20   30.0   48.0  17.0   81.0  1100.0
# 17263  17264  2015      2   18     7   10.0   10.0   7.0   24.0   500.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...
# 34314  34315  2017      1   28    18  244.0  301.0  61.0   83.0  2300.0
# 34334  34335  2017      1   29    14   13.0   48.0   5.0   15.0   100.0
# 34560  34561  2017      2    8     0  108.0  120.0  20.0   83.0   200.0
# 34638  34639  2017      2   11     6   16.0   38.0   8.0   75.0   100.0
# 34746  34747  2017      2   15    18  267.0  267.0  50.0  115.0  2000.0
#
#                O3       TEMP        PRES       DEWP      RAIN   wd      WSPM  \
# ...

# %%
Guanyuan_df.wd.value_counts()
# Out:
# NE     5140
# ENE    3950
# SW     3359
# E      2608
# NNE    2445
# WSW    2212
# SSW    2098
# N      2066
# NW     1860
# ESE    1717
# NNW    1589
# SE     1341
# S      1304
# W      1171
# WNW    1101
# SSE    1022
# Name: wd, dtype: int64

# %%
Guanyuan_df.fillna(value="NE", inplace=True)

# %%
Guanyuan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Gucheng_df[column].fillna(value=Gucheng_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Gucheng_df.isna().sum())
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         159
# WSPM         0
# station      0
# dtype: int64

# %%
Gucheng_df[Gucheng_df.wd.isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  \
# 2937    2938  2013      7    1     9  186.0  147.0   3.0   79.0  2000.0   3.0
# 3960    3961  2013      8   13     0   94.0   95.0   3.0   40.0  1100.0  59.0
# 3961    3962  2013      8   13     1   98.0   95.0   3.0   24.0  1000.0  72.0
# 3962    3963  2013      8   13     2   96.0  103.0   3.0   31.0  1100.0  52.0
# 3963    3964  2013      8   13     3  106.0  112.0   3.0   41.0  1100.0  36.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...   ...
# 34086  34087  2017      1   19     6   96.0  133.0  38.0   88.0  2800.0   4.0
# 34087  34088  2017      1   19     7  110.0  147.0  34.0   89.0  2800.0   5.0
# 34285  34286  2017      1   27    13   40.0   88.0  12.0   14.0   600.0  59.0
# 34470  34471  2017      2    4     6  263.0  295.0  79.0  132.0  4900.0   2.0
# 34975  34976  2017      2   25     7    3.0   20.0   3.0    6.0   400.0  55.0
#
# ...

# %%
Gucheng_df.wd.value_counts()
# Out:
# N      3949
# NE     3119
# SSW    2762
# NW     2758
# NNE    2602
# S      2343
# W      2331
# WNW    2073
# SW     1993
# ENE    1885
# WSW    1621
# NNW    1614
# E      1607
# SSE    1553
# ESE    1353
# SE     1342
# Name: wd, dtype: int64

# %%
Gucheng_df.fillna(value="N", inplace=True)

# %%
Gucheng_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Huairou_df[column].fillna(value=Huairou_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Huairou_df.isna().sum())
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         302
# WSPM         0
# station      0
# dtype: int64

# %%
Huairou_df[Huairou_df.wd.isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  \
# 14986  14987  2014     11   15    10   42.0   82.0  27.0   51.0  1000.0  10.0
# 15118  15119  2014     11   20    22  308.0  362.0   9.0  132.0  3700.0   2.0
# 15493  15494  2014     12    6    13    8.0    8.0   8.0   10.0   300.0  65.0
# 15899  15900  2014     12   23    11   53.0   78.0  27.0   48.0  1100.0  22.0
# 15900  15901  2014     12   23    12   47.0   74.0  26.0   41.0   900.0  31.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...   ...
# 34701  34702  2017      2   13    21  111.0  182.0  19.0   92.0  2800.0   4.0
# 34725  34726  2017      2   14    21  238.0  246.0  23.0   77.0  3100.0  40.0
# 34795  34796  2017      2   17    19   21.0   52.0   6.0   47.0   800.0  52.0
# 34875  34876  2017      2   21     3   23.0   36.0   6.0   21.0   100.0  30.0
# 35024  35025  2017      2   27     8   42.0   64.0   4.0   53.0  1300.0   5.0
#
# ...

# %%
Huairou_df.wd.value_counts()
# Out:
# NW     4943
# WNW    4876
# NE     2252
# E      2159
# W      2138
# SE     2113
# ENE    2026
# ESE    2022
# SW     1797
# NNE    1687
# NNW    1663
# SSE    1573
# WSW    1468
# N      1367
# SSW    1350
# S      1328
# Name: wd, dtype: int64

# %%
Huairou_df.fillna(value="NW", inplace=True)

# %%
Huairou_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Nongzhanguan_df[column].fillna(value=Nongzhanguan_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Nongzhanguan_df.isna().sum())
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         78
# WSPM        0
# station     0
# dtype: int64

# %%
Nongzhanguan_df[Nongzhanguan_df.wd.isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  \
# 16748  16749  2015      1   27    20   36.0   53.0  15.0   79.0  1000.0   5.0
# 17263  17264  2015      2   18     7   12.0   13.0  19.0   28.0   500.0  53.0
# 20853  20854  2015      7   17    21   53.0   63.0   4.0   48.0  1300.0  90.0
# 23035  23036  2015     10   16    19  285.0  285.0  26.0  138.0  2600.0  91.0
# 23059  23060  2015     10   17    19  354.0  354.0  16.0  184.0  2700.0  29.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...   ...
# 34314  34315  2017      1   28    18  220.0  260.0  50.0   54.0  2700.0  18.0
# 34334  34335  2017      1   29    14   12.0   39.0   4.0    8.0   300.0  68.0
# 34560  34561  2017      2    8     0  106.0  115.0  14.0   74.0  1900.0   3.0
# 34638  34639  2017      2   11     6    9.0   14.0   6.0   39.0   400.0  33.0
# 34746  34747  2017      2   15    18  252.0  252.0  48.0  125.0  2000.0  38.0
#
# ...

# %%
Nongzhanguan_df.wd.value_counts()
# Out:
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: wd, dtype: int64

# %%
Nongzhanguan_df.fillna(value="ENE", inplace=True)

# %%
Nongzhanguan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Shunyi_df[column].fillna(value=Shunyi_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Shunyi_df.isna().sum())
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         483
# WSPM         0
# station      0
# dtype: int64

# %%
Shunyi_df[Shunyi_df.wd.isna()]
# Out:
#           No  year  month  day  hour       PM2.5        PM10        SO2  \
# 6764    6765  2013     12    7    20  380.000000  378.000000  44.000000
# 16416  16417  2015      1   14     0  215.000000  215.000000  36.000000
# 16760  16761  2015      1   28     8    7.000000    7.000000   2.000000
# 16790  16791  2015      1   29    14   32.000000   32.000000   4.000000
# 16812  16813  2015      1   30    12   15.000000   15.000000   2.000000
# ...      ...   ...    ...  ...   ...         ...         ...        ...
# 34872  34873  2017      2   21     0   79.491602   98.737026  13.572039
# 34903  34904  2017      2   22     7   82.000000   82.000000   4.000000
# 34944  34945  2017      2   24     0   74.000000   80.000000  30.000000
# 34946  34947  2017      2   24     2   71.000000   86.000000  24.000000
# 35014  35015  2017      2   26    22   87.000000  118.000000  20.000000
#
#               NO2           CO         O3       TEMP         PRES       DEWP  \
# ...

# %%
Shunyi_df.wd.value_counts()
# Out:
# NNE    4540
# N      3877
# NE     3351
# SSE    2963
# SE     2665
# S      2613
# NW     2446
# WNW    2051
# NNW    1656
# SSW    1586
# ENE    1416
# ESE    1377
# W      1177
# E      1153
# SW      973
# WSW     737
# Name: wd, dtype: int64

# %%
Shunyi_df.fillna(value="NNE", inplace=True)

# %%
Shunyi_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Tiantan_df[column].fillna(value=Tiantan_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Tiantan_df.isna().sum())
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         78
# WSPM        0
# station     0
# dtype: int64

# %%
Tiantan_df[Tiantan_df.wd.isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  \
# 16748  16749  2015      1   27    20   26.0   35.0  12.0   60.0   800.0   6.0
# 17263  17264  2015      2   18     7   14.0   14.0  11.0   26.0   300.0  62.0
# 20853  20854  2015      7   17    21   73.0   76.0   4.0   33.0  1500.0  27.0
# 23035  23036  2015     10   16    19  220.0  220.0   2.0   90.0  2100.0  52.0
# 23059  23060  2015     10   17    19  280.0  280.0   2.0  120.0  2200.0  14.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...   ...
# 34314  34315  2017      1   28    18  230.0  296.0  27.0   69.0  2700.0   7.0
# 34334  34335  2017      1   29    14   11.0   55.0   2.0   18.0   400.0  62.0
# 34560  34561  2017      2    8     0   99.0  114.0   6.0   68.0  1700.0   2.0
# 34638  34639  2017      2   11     6   12.0   16.0   4.0   50.0   800.0  17.0
# 34746  34747  2017      2   15    18  237.0  237.0  28.0   94.0  2600.0  67.0
#
# ...

# %%
Tiantan_df.wd.value_counts()
# Out:
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: wd, dtype: int64

# %%
Tiantan_df.fillna(value="ENE", inplace=True)

# %%
Tiantan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Wanliu_df[column].fillna(value=Wanliu_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Wanliu_df.isna().sum())
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         123
# WSPM         0
# station      0
# dtype: int64

# %%
Wanliu_df[Wanliu_df.wd.isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2       NO2  \
# 6388    6389  2013     11   22     4  148.0  152.0  14.0   71.2391
# 11718  11719  2014      7    2     6   48.0   48.0   3.0   16.0000
# 13412  13413  2014      9   10    20   48.0  112.0  16.0   77.0000
# 16748  16749  2015      1   27    20   22.0   46.0  20.0   76.0000
# 17188  17189  2015      2   15     4  277.0  281.0  58.0  140.0000
# ...      ...   ...    ...  ...   ...    ...    ...   ...       ...
# 34286  34287  2017      1   27    14   42.0   67.0  13.0   18.0000
# 34314  34315  2017      1   28    18  233.0  279.0  58.0   95.0000
# 34334  34335  2017      1   29    14   12.0   43.0   5.0    5.0000
# 34420  34421  2017      2    2     4   88.0  111.0  29.0   74.0000
# 34639  34640  2017      2   11     7   19.0   41.0  16.0   83.0000
#
#                 CO         O3       TEMP         PRES       DEWP      RAIN  \
# 6388   1319.353513  48.873614  -3.200000  1020.500000  -4.000000  0.000000
# ...

# %%
Wanliu_df.wd.value_counts()
# Out:
# NE     6703
# SW     4644
# ENE    3642
# NNE    3327
# N      3219
# WSW    2529
# SSW    2101
# NNW    1397
# W      1335
# E      1264
# NW     1107
# S       966
# WNW     813
# SE      707
# SSE     615
# ESE     572
# Name: wd, dtype: int64

# %%
Wanliu_df.fillna(value="NE", inplace=True)

# %%
Wanliu_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    Wanshouxigong_df[column].fillna(value=Wanshouxigong_df[column].mean(), inplace=True)

# Verify if there are any remaining missing values
print(Wanshouxigong_df.isna().sum())
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         79
# WSPM        0
# station     0
# dtype: int64

# %%
Wanshouxigong_df[Wanshouxigong_df.wd.isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO  \
# 6388    6389  2013     11   22     4  143.0  146.0  38.0   86.0  3500.0
# 11720  11721  2014      7    2     8   42.0   42.0   2.0   39.0   800.0
# 17263  17264  2015      2   18     7   16.0   16.0  11.0   31.0   400.0
# 20853  20854  2015      7   17    21   61.0   80.0   2.0   45.0  1700.0
# 23035  23036  2015     10   16    19  259.0  263.0   7.0  108.0  2400.0
# ...      ...   ...    ...  ...   ...    ...    ...   ...    ...     ...
# 34314  34315  2017      1   28    18  257.0  281.0  48.0   75.0  2800.0
# 34334  34335  2017      1   29    14   13.0   46.0   4.0    6.0   300.0
# 34560  34561  2017      2    8     0  104.0  113.0  17.0   87.0  1900.0
# 34638  34639  2017      2   11     6   10.0   15.0   7.0   56.0   800.0
# 34746  34747  2017      2   15    18  259.0  259.0  43.0  127.0  2000.0
#
#             O3       TEMP         PRES       DEWP     RAIN   wd      WSPM  \
# ...

# %%
Wanshouxigong_df.wd.value_counts()
# Out:
# NE     3568
# SW     3428
# ENE    3080
# E      2807
# WNW    2565
# NW     2552
# WSW    2546
# W      2464
# SSW    2457
# ESE    1772
# NNE    1564
# S      1506
# SE     1279
# NNW    1187
# N      1176
# SSE    1034
# Name: wd, dtype: int64

# %%
Wanshouxigong_df.fillna(value="NE", inplace=True)

# %%
Wanshouxigong_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# - Melakukan concat untuk menggabungkan file - file .csv

# %%
csv_files = [
    "PRSA_Data_Aotizhongxin_20130301-20170228.csv",
    "PRSA_Data_Changping_20130301-20170228.csv",
    "PRSA_Data_Dingling_20130301-20170228.csv",
    "PRSA_Data_Dongsi_20130301-20170228.csv",
    "PRSA_Data_Guanyuan_20130301-20170228.csv",
    "PRSA_Data_Gucheng_20130301-20170228.csv",
    "PRSA_Data_Huairou_20130301-20170228.csv",
    "PRSA_Data_Nongzhanguan_20130301-20170228.csv",
    "PRSA_Data_Shunyi_20130301-20170228.csv",
    "PRSA_Data_Tiantan_20130301-20170228.csv",
    "PRSA_Data_Wanliu_20130301-20170228.csv",
    "PRSA_Data_Wanshouxigong_20130301-20170228.csv"
]

dataframes = [pd.read_csv(file) for file in csv_files]
appended_df = pd.concat(dataframes, axis=0, ignore_index=True)

# Output
appended_df.to_csv('result_appended.csv', index=False)
appended_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       420768 non-null  int64
#  1   year     420768 non-null  int64
#  2   month    420768 non-null  int64
#  3   day      420768 non-null  int64
#  4   hour     420768 non-null  int64
#  5   PM2.5    412029 non-null  float64
#  6   PM10     414319 non-null  float64
#  7   SO2      411747 non-null  float64
#  8   NO2      408652 non-null  float64
#  9   CO       400067 non-null  float64
#  10  O3       407491 non-null  float64
#  11  TEMP     420370 non-null  float64
#  12  PRES     420375 non-null  float64
#  13  DEWP     420365 non-null  float64
#  14  RAIN     420378 non-null  float64
#  15  wd       418946 non-null  object
#  16  WSPM     420450 non-null  float64
#  17  station  420768 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 57.8+ MB

# %%
appended_df.isna().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5       8739
# PM10        6449
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# dtype: int64

# %% [markdown]
# - Melakukan Cleaning Data pada file yang sudah disatukan

# %%
columns_to_fill = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

for column in columns_to_fill:
    appended_df[column].fillna(value=appended_df[column].mean(), inplace=True)

print(appended_df.isna().sum())
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5         0
# PM10          0
# SO2           0
# NO2           0
# CO            0
# O3            0
# TEMP          0
# PRES          0
# DEWP          0
# RAIN          0
# wd         1822
# WSPM          0
# station       0
# dtype: int64

# %%
appended_df.wd.value_counts()
# Out:
# NE     43335
# ENE    34142
# NW     32600
# N      30869
# E      29752
# SW     28756
# NNE    28232
# NNW    25326
# WNW    24375
# ESE    24220
# SSW    22563
# SE     20074
# WSW    20040
# S      19405
# SSE    17694
# W      17563
# Name: wd, dtype: int64

# %%
appended_df.fillna(value="NE", inplace=True)

appended_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# - Melakukan pengecekan type data

# %%
appended_df.dtypes
# Out:
# No           int64
# year         int64
# month        int64
# day          int64
# hour         int64
# PM2.5      float64
# PM10       float64
# SO2        float64
# NO2        float64
# CO         float64
# O3         float64
# TEMP       float64
# PRES       float64
# DEWP       float64
# RAIN       float64
# wd          object
# WSPM       float64
# station     object
# dtype: object

# %%
appended_df.sample(5)
# Out:
#            No  year  month  day  hour  PM2.5   PM10   SO2   NO2      CO  \
# 89613   19486  2015      5   21    21   22.0   96.0   4.0  13.0   300.0
# 11428   11429  2014      6   20     4   37.0   37.0   4.0  29.0   400.0
# 325284   9709  2014      4    9    12   38.0   36.0   7.0  21.0   400.0
# 120145  14954  2014     11   14     1   31.0   75.0  10.0  74.0  1700.0
# 340347  24772  2015     12   28     3  107.0  107.0   3.0  65.0  3000.0
#
#            O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# 89613   117.0  23.3  1000.4   7.8   0.0  ENE   1.6      Dingling
# 11428    35.0  19.1  1001.4  19.1   0.6  ENE   0.9  Aotizhongxin
# 325284  114.0  29.1  1004.0  -4.4   0.0  WNW   4.9       Tiantan
# 120145    2.0   0.0  1018.0  -7.1   0.0  ENE   1.2        Dongsi
# 340347    2.0  -7.3  1032.6 -11.7   0.0   NE   1.5       Tiantan

# %%
appended_df.describe(include="all")
# Out:
#                    No           year          month            day  \
# count   420768.000000  420768.000000  420768.000000  420768.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean     17532.500000    2014.662560       6.522930      15.729637
# std      10122.116943       1.177198       3.448707       8.800102
# min          1.000000    2013.000000       1.000000       1.000000
# 25%       8766.750000    2014.000000       4.000000       8.000000
# 50%      17532.500000    2015.000000       7.000000      16.000000
# 75%      26298.250000    2016.000000      10.000000      23.000000
# max      35064.000000    2017.000000      12.000000      31.000000
#
#                  hour          PM2.5           PM10            SO2  \
# count   420768.000000  420768.000000  420768.000000  420768.000000
# ...

# %% [markdown]
# - Melakukan Eksplorasi dengan mengelompokan berdasarkan stasiun

# %%
# Kelompokkan berdasarkan stasiun dan perhitungan statistik kuantitatif
station_stats = df.groupby('station').agg({
    'PM2.5': ['mean', 'median', 'std', 'min', 'max'],
    'PM10': ['mean', 'median', 'std', 'min', 'max'],
    'SO2': ['mean', 'median', 'std', 'min', 'max'],
    'NO2': ['mean', 'median', 'std', 'min', 'max'],
    'CO': ['mean', 'median', 'std', 'min', 'max'],
    'O3': ['mean', 'median', 'std', 'min', 'max']
}).reset_index()

# Menampilkan statistik berdasarkan stasiun
print(station_stats)
# Out:
#           station      PM2.5                                      PM10         \
#                         mean median        std  min    max        mean median
# 0    Aotizhongxin  82.773611   58.0  82.135694  3.0  898.0  110.060391   87.0
# 1       Changping  71.099743   46.0  72.326926  2.0  882.0   94.657871   72.0
# 2        Dingling  65.989497   41.0  72.267723  3.0  881.0   83.739723   60.0
# 3          Dongsi  86.194297   61.0  86.575127  3.0  737.0  110.336742   86.0
# 4        Guanyuan  82.933372   59.0  80.933497  2.0  680.0  109.023303   89.0
# 5         Gucheng  83.852089   60.0  82.796445  2.0  770.0  118.861978   99.0
# 6         Huairou  69.626367   47.0  71.224916  2.0  762.0   91.482690   69.0
# 7    Nongzhanguan  84.838483   59.0  86.225344  2.0  844.0  108.991096   85.0
# 8          Shunyi  79.491602   55.0  81.231739  2.0  941.0   98.737026   77.0
# 9         Tiantan  82.164911   59.0  80.921384  3.0  821.0  106.363672   85.0
# ...

# %% [markdown]
# - Melakukan eksplorasi denan mengelompokan berdasarkan tahun, bulan, serta jam

# %%
# Pengelompokan berdasarkan tahun, bulan, dan jam dan perhitungan statistik kuantitatif
time_stats = df.groupby(['year', 'month', 'hour']).agg({
    'PM2.5': 'mean',
    'PM10': 'mean',
    'SO2': 'mean',
    'NO2': 'mean',
    'CO': 'mean',
    'O3': 'mean'
}).reset_index()

# Menampilkan statistik waktu
print(time_stats)
# Out:
#       year  month  hour       PM2.5        PM10        SO2        NO2  \
# 0     2013      3     0  111.894595  129.045822  35.007219  73.962054
# 1     2013      3     1  108.981081  123.733154  33.829018  70.423169
# 2     2013      3     2  103.072973  120.714286  32.518042  65.586178
# 3     2013      3     3   94.989189  111.018868  30.579066  62.732209
# 4     2013      3     4   94.000000  107.472973  29.406456  63.208794
# ...    ...    ...   ...         ...         ...        ...        ...
# 1147  2017      2    19   68.916418   93.940299  14.988060  55.126506
# 1148  2017      2    20   73.101493   99.850746  16.519403  59.936937
# 1149  2017      2    21   75.077844  101.844311  18.092814  61.408408
# 1150  2017      2    22   79.134328  104.202985  19.856716  61.302395
# 1151  2017      2    23   81.337313  101.104478  20.280597  60.425150
#
#                CO         O3
# 0     1559.232955  51.998021
# 1     1521.783476  52.763169
# 2     1471.848571  52.885782
# ...

# %% [markdown]
# - Melakukan eksplorasi hubungan antar polutan

# %%
# Hitung matriks korelasi antar polutan
correlation_matrix = df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].corr()

# Tampilkan matriks korelasi
print(correlation_matrix)
# Out:
#           PM2.5      PM10       SO2       NO2        CO        O3
# PM2.5  1.000000  0.884380  0.482354  0.666948  0.789998 -0.149697
# PM10   0.884380  1.000000  0.462651  0.652193  0.702363 -0.111294
# SO2    0.482354  0.462651  1.000000  0.499496  0.535750 -0.165341
# NO2    0.666948  0.652193  0.499496  1.000000  0.705500 -0.471587
# CO     0.789998  0.702363  0.535750  0.705500  1.000000 -0.313012
# O3    -0.149697 -0.111294 -0.165341 -0.471587 -0.313012  1.000000

# %%
- Melakukan filter rata rata sedari tahun 2013 hingga 2017

# %%
# Filter 2013 - 2017
subset_years = df[(df['year'] >= 2013) & (df['year'] <= 2017)]

# Hitung tingkat polusi rata-rata setiap tahun
yearly_average = subset_years.groupby('year').agg({
    'PM2.5': 'mean',
    'PM10': 'mean',
    'SO2': 'mean',
    'NO2': 'mean',
    'CO': 'mean',
    'O3': 'mean'
}).reset_index()

# Menampilkan tingkat polusi rata-rata per tahun
print(yearly_average)
# Out:
#    year      PM2.5        PM10        SO2        NO2           CO         O3
# 0  2013  80.040536  102.823208  20.048420  52.534040  1203.131299  57.326222
# 1  2014  85.575700  116.126691  20.878454  54.781129  1256.904078  58.307991
# 2  2015  79.626788  103.613500  13.014975  48.191862  1257.823438  59.240321
# 3  2016  71.930151   94.615609   9.799084  46.395580  1138.790118  57.455946
# 4  2017  92.675992  111.117149  18.136980  57.331760  1599.710005  39.914663

# %% [markdown]
# - Melakukan eksplorasi untuk mencari rata rata tingkat PM2.5 tertinggi

# %%
# Tingkat polusi rata-rata setiap bulan
monthly_average = df.groupby(['year', 'month']).agg({
    'PM2.5': 'mean',
    'PM10': 'mean',
    'SO2': 'mean',
    'NO2': 'mean',
    'CO': 'mean',
    'O3': 'mean'
}).reset_index()

# Identifikasi bulan dengan rata-rata tingkat PM2.5 tertinggi
highest_pm25_months = monthly_average.sort_values(by='PM2.5', ascending=False).head(5)

# Tampilkan bulan dengan rata-rata tingkat PM2.5 tertinggi
print("Top 5 Months with Highest Average PM2.5 Levels:")
print(highest_pm25_months)
# Out:
# Top 5 Months with Highest Average PM2.5 Levels:
#     year  month       PM2.5        PM10        SO2        NO2           CO  \
# 33  2015     12  150.518426  160.164979  19.436061  74.544178  2749.816050
# 11  2014      2  148.322973  151.338195  56.665098  69.037632  2109.322720
# 45  2016     12  129.192047  149.899504  17.070395  77.751529  2426.001832
# 19  2014     10  118.579906  145.373245   8.736737  69.831192  1324.873156
# 32  2015     11  115.484985  120.921239  11.809829  59.814551  1934.825457
#
#            O3
# 33  17.151519
# 11  27.187440
# 45  17.760431
# 19  27.488015
# 32  14.449506

# %% [markdown]
# - Melakukan penecekan peningkatan polusi udara tiap tahun dan bulan

# %%
# Pivot table untuk melihat peningkatan polusi udara per tahun dan bulan
pivot_table_pm25 = pd.pivot_table(appended_df, values='PM2.5', index=['year', 'month'], aggfunc='mean').reset_index()

# Tampilkan pivot table
print("Pivot Table: Peningkatan Polusi Udara per Tahun dan Bulan")
print(pivot_table_pm25)
# Out:
# Pivot Table: Peningkatan Polusi Udara per Tahun dan Bulan
#     year  month       PM2.5
# 0   2013      3  104.756193
# 1   2013      4   62.269882
# 2   2013      5   81.773108
# 3   2013      6  101.867367
# 4   2013      7   68.395229
# 5   2013      8   60.741829
# 6   2013      9   76.133222
# 7   2013     10   91.880877
# 8   2013     11   73.900683
# 9   2013     12   78.459644
# 10  2014      1   97.649621
# 11  2014      2  145.416586
# 12  2014      3   95.015454
# 13  2014      4   90.447216
# 14  2014      5   62.225616
# 15  2014      6   55.173200
# 16  2014      7   89.744890
# 17  2014      8   63.530788
# 18  2014      9   66.512273
# 19  2014     10  117.715378
# 20  2014     11   86.819252
# 21  2014     12   59.198471
# 22  2015      1   96.191871
# 23  2015      2   93.020886
# 24  2015      3   86.437180
# 25  2015      4   71.458611
# 26  2015      5   55.970740
# 27  2015      6   61.313307
# 28  2015      7   61.245453
# 29  2015      8   44.975234
# ...

# %% [markdown]
# - Membuat heatmap untuk melihat korelasi antara 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM'

# %%
# Pilih kolom yang ingin diambil untuk heatmap
selected_columns = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']

# Hitung matriks korelasi antar kolom terpilih
correlation_matrix = df[selected_columns].corr()

# Plot heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap')
plt.show()

# %% [markdown]
# Dalam dataset ini, terlihat adanya hubungan erat antara beberapa variabel. Beberapa temuan menarik mencakup:
#
# Partikel Udara (PM2.5 dan PM10): Terdapat korelasi tinggi antara kandungan PM2.5 dan PM10, menunjukkan bahwa kedua jenis partikel tersebut cenderung berasal dari sumber yang sama.
#
# Partikel Udara (PM2.5/PM10) dan CO: Korelasi positif antara rasio PM2.5/PM10 dan kandungan CO menunjukkan adanya potensi polutan bersumber dari sumber yang sama.
#
# Suhu (TEMP), Tekanan Udara (PRES), dan Titik Embun (DEWP): Variabel-variabel ini menunjukkan korelasi, menunjukkan bahwa perubahan suhu dapat memengaruhi tekanan udara dan titik embun.
#
# CO dan NO2: Terdapat korelasi antara kandungan CO dan NO2, mengindikasikan kemungkinan hubungan antara dua jenis polutan ini.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana peningkatan polusi udara pada tahun 2013 hinga 2017?

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=pivot_table_pm25, x='year', y='PM2.5')
plt.title('Peningkatan Polusi Udara (PM2.5) per Tahun')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata PM2.5')
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Apakah ada bulan-bulan tertentu yang tingkat polusi udaranya selalu lebih tinggi?

# %%
# Pivot table untuk melihat rata-rata PM2.5 per bulan
pivot_table_monthly = pd.pivot_table(appended_df, values='PM2.5', index='month', aggfunc='mean').reset_index()

# Sorting pivot table berdasarkan rata-rata PM2.5
pivot_table_monthly = pivot_table_monthly.sort_values(by='PM2.5', ascending=False)

# Visualisasi bar chart
plt.figure(figsize=(12, 6))
sns.barplot(data=pivot_table_monthly, x='month', y='PM2.5', palette='viridis')
plt.title('Rata-rata Polusi Udara (PM2.5) per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Rata-rata PM2.5')
plt.show()
# Out:
# <ipython-input-355-3477c2009807>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=pivot_table_monthly, x='month', y='PM2.5', palette='viridis')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Selama periode 2013-2015, kita dapat mengamati tren penurunan yang cukup stabil dalam tingkat polusi udara, khususnya PM2.5. Pada awal periode, tingkat PM2.5 mencapai angka sekitar 100 dan kemudian secara konsisten mengalami penurunan hingga mencapai sekitar 80 pada pertengahan tahun 2015.
# Namun, setelah tahun 2015, kita melihat adanya perubahan tren yang signifikan
# Terjadi peningkatan tajam dalam tingkat polusi udara, dan pada pertengahan tahun 2017, tingkat PM2.5 bahkan melampaui angka sebelum penurunan pada tahun 2015. Kondisi ini menunjukkan bahwa setelah periode penurunan yang stabil, terjadi fluktuasi yang signifikan dan peningkatan kembali dalam tingkat polusi udara, yang memerlukan perhatian khusus dalam pemantauan dan pengelolaan kualitas udara di wilayah tersebut.
# - Berdasarkan analisis grafik, dapat disimpulkan bahwa tidak terdapat pola konsisten dari bulan ke bulan di mana tingkat polusi udara selalu lebih tinggi. Meskipun demikian, dari data yang ada, terlihat bahwa bulan Januari dan Februari cenderung memiliki tingkat polusi udara yang paling tinggi. Hal ini dapat menunjukkan adanya faktor-faktor tertentu, seperti kondisi cuaca atau pola emisi, yang berkontribusi pada peningkatan polusi udara pada periode tersebut.

# %%
appended_df.to_csv("all_data.csv", index=False)
